# %% [markdown]
# # Projeto 1 - Ciência dos Dados
#
# #### Feito por: Gabriel Kabbani

# %% [markdown]
# # Motivação:
#
# O projeto é inspirado pela verificação dos objetivos econômicos da União Européia. Em seus objetivos, constam os seguintes:
#
# 1. Desenvolvimento sustentável baseado no crescimento econômico equilibrado e na estabilidade de preços, uma economia de mercado altamente competitiva com pleno emprego e progresso social, e proteção ambiental.
#
# 2. Reforçar a coesão económica, social e territorial e a solidariedade entre os países da UE.
#
# Dessa forma, é interessante verificar até que ponto a suposta "coesão econômica" e o "crescimento econômico equilibrado" de fato fazem um impacto na economia. Para isso, esse projeto será destinado à comparação de índices econômicos entre os países que participam da União Européia e aqueles que não fazem parte.

# %% [markdown]
# # Pergunta:
#
# Com relação à totalidade dos países no mundo, com ênfase nos europeus, existe uma vantagem econômica por estar na União Européia, considerando PIB, exportações, e investimento estrangeiro?

# %% [markdown]
# # Bases de dado utilizadas:
#
# Bases de dado do gapminder utilizadas:
# 1. Foreign Direct Investment Net Inflows as Percent of GDP.
# 2. Exports as Percent of GDP.
# 3. GDP Per Capita US Inflation Adjusted.
# 4. HDI Human Development Index.
#
# Todas podem ser encontradas no seguinte link: https://www.gapminder.org/data/

# %% [markdown]
# # Hipótese e Mecanismo:
#
# Considerando os objetivos mencionados acima, pode se dizer que o participar da União Européia, o comércio com os outros países participantes é bastante facilitado, algo que não somente aumenta os mercados consumidores, mas que também estimula a economia local e os investimentos estrangeiros nela, fazendo com que o PIB e a quantidade de exportações sejam maiores. Essa hipótese foi em parte fundamentada por pesquisas que exploram os benefícios da União Européia, como a disponível no site 'econ.economicshelp.org', referenciada no final do projeto.
#
# Para responder a pergunta e verificar a hipótese acima, vou analisar os anos 2010, 2014, e 2017 de todos os países cujos dados estão disponíveis, para ter uma análise geral referente à esta última década, começando após a crise de 2008, para mostrar o impacto da união ao longo do tempo, mesmo em períodos de recuperação, mas sem ter os dados possívelmente influenciados de maneira considerável pela crise, algo que poderia ter acontecido caso anos anteriores fossem escolhidos. Vale ressaltar que o foco da análise é a tendência de cada índice durante a década de 2010, especialmente no início (que mostra o período depois da crise), e devido a isso foram utilizados somente estes anos, ao invés de todos os anos disponíveis, uma vez que eles já conseguem prover a noção necessária sobre o período. Ademais, para analisá-los, vou utilizar o PIB per capita (ajustado pela inflação americana ao longo dos anos), a quantidade de investimento estrangeiro sendo alocado no país, como porcentagem do PIB, e as o capital decorrido de exportações, também como porcentagem do PIB. Estes indicadores possibilitam diversar análises sobre a situação econômica do país, sendo ótimas ferramentas responder a pergunta acima.
#
# Mais especificamente, os indicadores serão utilizados para comparar a variação entre os três grupos de países (que pertencem à União Européia, que são europeus mas não pertencem, e os países não europeus) ao decorrer dos anos escolhidos. Assim, poderei investigar a inclinação com qual cresce os indicadores de cada grupo, para ver as diferenças no desenvolvimento econômico médio entre eles. Além disso, poderei investigar como cada observação pode ou não ser resultado do pertencimento à união, e se o crescimento ocorre somente nos países mais desenvolvidos. Para isso, utilizarei o Índice de Desenvolvimento Humano, adicionando uma outra camada de análises, para ter certeza de que um eventual crescimento ocorre devido à União Européia, e não somente pelo país ser mais desenvolvido. Infelizmente, só estão disponíveis os dados de IDH até 2015 (a partir disso somente poucos países podem ser facilmente integrados, algo que comprometeria a análise), então essa análise com relação ao desenvolvimento será limitada aos anos de 2010, 2013, 2015.

# %% [markdown]
# # Montagem do database:

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
import os
print (os.getcwd())
# Out:
# /Users/Kabbani/Desktop/Insper/Ciência dos Dados/P1/P1_GIT/Projeto-1-CD-Gabriel-Kabbani-

# %%
dados_export = pd.read_excel('exports_percent_of_gdp.xlsx')
dados_gdp = pd.read_excel('gdppercapita_us_inflation_adjusted.xlsx')
dados_fdi = pd.read_excel('foreign_direct_investment_net_inflows_percent_of_gdp.xlsx')
dados_idh= pd.read_excel('hdi_human_development_index.xlsx')

# %%
dados_gdp.insert(1, "EU", 0)
dados_gdp.loc[(dados_gdp.country == 'Albania') | (dados_gdp.country == 'Andorra') | (dados_gdp.country == 'Belarus') | (dados_gdp.country == 'Bosnia and Herzegovina') | (dados_gdp.country == 'Iceland') | (dados_gdp.country == 'Liechtenstein') | (dados_gdp.country == 'Macedonia') | (dados_gdp.country == 'Moldova') | (dados_gdp.country == 'Monaco') | (dados_gdp.country == 'Montenegro') | (dados_gdp.country == 'Norway')| (dados_gdp.country == 'Russia') | (dados_gdp.country == 'San Marino') | (dados_gdp.country == 'Serbia') | (dados_gdp.country == 'Switzerland') | (dados_gdp.country == 'Turkey') | (dados_gdp.country == 'Ukraine') , ['EU']]='1'
dados_gdp.loc[(dados_gdp.country == 'Austria') | (dados_gdp.country == 'Belgium')| (dados_gdp.country == 'Bulgaria')| (dados_gdp.country == 'Croatia')| (dados_gdp.country == 'Cyprus')| (dados_gdp.country == 'Czech Republic') | (dados_gdp.country == 'Denmark') | (dados_gdp.country == 'Estonia') | (dados_gdp.country == 'Finland') | (dados_gdp.country == 'France') | (dados_gdp.country == 'Germany') | (dados_gdp.country == 'Greece') | (dados_gdp.country == 'Hungary') | (dados_gdp.country == 'Ireland') | (dados_gdp.country == 'Italy') | (dados_gdp.country == 'Latvia') | (dados_gdp.country == 'Lithuania') | (dados_gdp.country == 'Luxembourg') | (dados_gdp.country == 'Malta') | (dados_gdp.country == 'Netherlands') | (dados_gdp.country == 'Poland') | (dados_gdp.country == 'Portugal') | (dados_gdp.country == 'Romania') | (dados_gdp.country == 'Slovak Republic') | (dados_gdp.country == 'Slovenia') | (dados_gdp.country == 'Spain') | (dados_gdp.country == 'Sweden') | (dados_gdp.country == 'United Kingdom'),['EU']] = '2'
dados_gdp.EU= dados_gdp.EU.astype('category')
dados_gdp.EU.cat.categories=['Não-Europeu','Europeu-não-participante','Participante']

# %%
gdp_2010_14_17 = dados_gdp.loc[:,['country',"EU",2010,2014,2017]]
exp_2010_14_17 = dados_export.loc[:,['country',2010,2014,2017]]
fdi_2010_14_17 = dados_fdi.loc[:,['country',2010,2014,2017]]
idh_2010_13_15 = dados_idh.loc[:,['country',2010,2013,2015]]

# %%
gdp = gdp_2010_14_17.set_index('country')     #('GDP per capita inflation-adjusted')
exp = exp_2010_14_17.set_index('country')     #('Exports as % of GDP')
fdi = fdi_2010_14_17.set_index('country')     #('Foreign Direct Investment as % of GDP')
idh = idh_2010_13_15.set_index('country')

# %%
data = gdp.join(exp, how='inner', lsuffix='_PIB', rsuffix='_Exports')
data = data.join(fdi,how='inner', rsuffix='_FDI')
data.rename(columns={2010:"2010_FDI",2014:"2014_FDI",2017:"2017_FDI","EU":"UE"}, inplace=True)
data = data.join(idh,how='inner', rsuffix='_IDH')
data.rename(columns={2010:"2010_IDH",2013:"2013_IDH",2015:"2015_IDH"}, inplace=True)
data.head()
# Out:
#                                            UE  2010_PIB  2014_PIB  2017_PIB  \
# country
# Afghanistan                       Não-Europeu       553     630.0     618.0
# Albania              Europeu-não-participante      4090    4410.0    4870.0
# Algeria                           Não-Europeu      4460    4680.0    4830.0
# Angola                            Não-Europeu      3530    3750.0    3480.0
# Antigua and Barbuda               Não-Europeu     12200   12400.0   13600.0
#
#                      2010_Exports  2014_Exports  2017_Exports  2010_FDI  \
# country
# Afghanistan                  10.0          6.57           NaN      1.20
# Albania                      28.0         28.20          31.5      9.14
# Algeria                      38.4         30.20          24.0      1.43
# Angola                       62.3         48.00          29.9     -3.91
# Antigua and Barbuda          45.5         46.10           NaN      8.39
#
# ...

# %% [markdown]
# Como pode se evidenciar na célula abaixo, quatro países europeus não participantes estão faltando na tabela, devido à falta de dados, que comprometeria severamente a análise. Mesmo assim, a análise continua válida sem esses países pelo fato de ainda haverem vários outros para fornecer os dados necessários.

# %%
data.UE.value_counts()
# Out:
# Não-Europeu                 139
# Participante                 28
# Europeu-não-participante     12
# Name: UE, dtype: int64

# %% [markdown]
# # Análise dos Dados:

# %%
uniao= data[data.UE == 'Participante']
euro= data[data.UE == 'Europeu-não-participante']
ne= data[data.UE == 'Não-Europeu']


data.describe()
# Out:
#             2010_PIB      2014_PIB       2017_PIB  2010_Exports  2014_Exports  \
# count     179.000000     177.00000     175.000000    176.000000    176.000000
# mean    12388.016760   13024.59322   13702.468571     40.872722     42.404375
# std     17862.157767   18289.42942   19134.098953     26.815091     28.193350
# min       231.000000     243.00000     213.000000      0.109000      1.830000
# 25%      1340.000000    1650.00000    1895.000000     23.800000     25.275000
# 50%      4560.000000    5430.00000    5560.000000     35.300000     37.000000
# 75%     13300.000000   14700.00000   15700.000000     50.825000     50.875000
# max    105000.000000  107000.00000  108000.000000    200.000000    208.000000
#
#        2017_Exports    2010_FDI    2014_FDI    2017_FDI    2010_IDH  \
# count    140.000000  179.000000  178.000000  174.000000  179.000000
# mean      41.720357    6.521645    4.357730    4.064777    0.677419
# ...

# %% [markdown]
# ## PIB:

# %%
def verticalLine(plot, x, y, color, nome):
    plot.axvline(x, color=color, linestyle="dashed", linewidth=2)
    plot.text(1.01*x, y, nome, color=color) 

fig = plt.figure(figsize=(15, 15))
def plots(grupo,coluna,nome,plot,cor,pos1,pos2):
    plt.subplot(plot)
    plot = grupo[coluna].plot.hist(bins=5, title='{0}: {1}'.format(nome, coluna), alpha=0.9, color=cor)
    plt.ylabel('Frequência Absoluta')
    plt.xlabel('PIB (ajustado à inflação) em USD')
    verticalLine(plot, grupo[coluna].mean(), pos1, "purple", "Média")
    verticalLine(plot, grupo[coluna].median(), pos2, "black", "Mediana")

plots(uniao,'2010_PIB','UE',331,'b',12,10)
plots(uniao,'2014_PIB','UE',332,'b',12,10)
plots(uniao,'2017_PIB','UE',333,'b',12,10)
plots(euro,'2010_PIB','Europeus não participantes',334,'r',8,6)
plots(euro,'2014_PIB','Europeus não participantes',335,'r',8,6)
plots(euro,'2017_PIB','Europeus não participantes',336,'r',8,6)
plots(ne,'2010_PIB','Não Europeus',337,'g',110,100)
plots(ne,'2014_PIB','Não Europeus',338,'g',110,100)
plots(ne,'2017_PIB','Não Europeus',339,'g',110,100)

# %%
media_GDP_UE_2010= uniao['2010_PIB'].mean()
media_GDP_Europeus_2010= euro['2010_PIB'].mean()
media_GDP_NE_2010= ne['2010_PIB'].mean()

media_GDP_UE_2014= uniao['2014_PIB'].mean()
media_GDP_Europeus_2014= euro['2014_PIB'].mean()
media_GDP_NE_2014= ne['2014_PIB'].mean()

media_GDP_UE_2017= uniao['2017_PIB'].mean()
media_GDP_Europeus_2017= euro['2017_PIB'].mean()
media_GDP_NE_2017= ne['2017_PIB'].mean()

media_GDP_UE = (media_GDP_UE_2010 + media_GDP_UE_2014 + media_GDP_UE_2017)/3
media_GDP_Europeus= (media_GDP_Europeus_2010 + media_GDP_Europeus_2014 + media_GDP_Europeus_2017)/3
media_GDP_NE = (media_GDP_NE_2010 + media_GDP_NE_2014 + media_GDP_NE_2017)/3

medias_gdp = {'União Européia': media_GDP_UE , 'Europeus não participantes': media_GDP_Europeus , 'Não Europeus':media_GDP_NE}
names=list(medias_gdp.keys())
values=list(medias_gdp.values()) 

plt.bar(names,values, color = ('blue','red','green'))
plt.title("PIB")
plt.ylabel('PIB (ajustado à inflação) em USD')
plt.show()

# %%
anos= [2010,2014,2017]
medias_gdp_UE=[media_GDP_UE_2010, media_GDP_UE_2014, media_GDP_UE_2017]
medias_gdp_Europeus=[media_GDP_Europeus_2010, media_GDP_Europeus_2014, media_GDP_Europeus_2017]
medias_gdp_NE=[media_GDP_NE_2010, media_GDP_NE_2014, media_GDP_NE_2017]

plt.scatter(anos,medias_gdp_UE, label = 'União Européia', color= 'b')
z = np.polyfit(anos, medias_gdp_UE, 1)
p = np.poly1d(z)
plt.plot(anos,p(anos),"b--")


plt.scatter(anos,medias_gdp_Europeus, label = 'Europeu não participante', color = 'r')
z = np.polyfit(anos, medias_gdp_Europeus, 1)
p = np.poly1d(z)
plt.plot(anos,p(anos),"r--")


plt.scatter(anos,medias_gdp_NE, label = 'Não Europeu', color = 'g')
z = np.polyfit(anos, medias_gdp_NE, 1)
p = np.poly1d(z)
plt.plot(anos,p(anos),"g--")


plt.legend(loc='center left', bbox_to_anchor=(1, 0.5))
plt.ylabel('PIB (ajustado à inflação) em USD')
plt.xlabel('Anos')
plt.title('PIB')
plt.show()

#tentar achar coeficiente angular das retas. taxa de variacao.

# %% [markdown]
# ## Investimento Estrangeiro:

# %%
fig = plt.figure(figsize=(15, 15))
def plots(grupo,coluna,nome,plot,cor,pos1,pos2):
    plt.subplot(plot)
    plot = grupo[coluna].plot.hist(bins=5, title='{0}: {1}'.format(nome, coluna), alpha=0.9, color=cor)
    plt.ylabel('Frequência Absoluta')
    plt.xlabel('Entrada de investimentos estrangeiros como % do PIB')
    verticalLine(plot, grupo[coluna].mean(), pos1, "b", "Média")
    verticalLine(plot, grupo[coluna].median(), pos2, "black", "Mediana")

plots(uniao,'2010_FDI','UE',331,'r',15,12)
plots(uniao,'2014_FDI','UE',332,'r',15,12)
plots(uniao,'2017_FDI','UE',333,'r',15,12)
plots(euro,'2010_FDI','Europeus não participantes',334,'g',6,5)
plots(euro,'2014_FDI','Europeus não participantes',335,'g',4,3)
plots(euro,'2017_FDI','Europeus não participantes',336,'g',6,5)
plots(ne,'2010_FDI','Não Europeus',337,'yellow',110,100)
plots(ne,'2014_FDI','Não Europeus',338,'yellow',50,60)
plots(ne,'2017_FDI','Não Europeus',339,'yellow',70,60)

# %%
media_FDI_UE_2010= uniao['2010_FDI'].mean()
media_FDI_Europeus_2010= euro['2010_FDI'].mean()
media_FDI_NE_2010= ne['2010_FDI'].mean()

media_FDI_UE_2014= uniao['2014_FDI'].mean()
media_FDI_Europeus_2014= euro['2014_FDI'].mean()
media_FDI_NE_2014= ne['2014_FDI'].mean()

media_FDI_UE_2017= uniao['2017_FDI'].mean()
media_FDI_Europeus_2017= euro['2017_FDI'].mean()
media_FDI_NE_2017= ne['2017_FDI'].mean()

media_FDI_UE = (media_FDI_UE_2010 + media_FDI_UE_2014 + media_FDI_UE_2017)/3
media_FDI_Europeus= (media_FDI_Europeus_2010 + media_FDI_Europeus_2014 + media_FDI_Europeus_2017)/3
media_FDI_NE = (media_FDI_NE_2010 + media_FDI_NE_2014 + media_FDI_NE_2017)/3

medias_fdi = {'União Européia': media_FDI_UE , 'Europeus não participantes': media_FDI_Europeus , 'Não Europeus':media_FDI_NE}
names=list(medias_fdi.keys())
values=list(medias_fdi.values())

plt.bar(names,values, color = ('r','g','yellow'))
plt.title("FDI")
plt.ylabel('Entrada de investimentos estrangeiros como % do PIB')
plt.show()

# %%
anos= [2010,2014,2017]
medias_fdi_UE=[media_FDI_UE_2010, media_FDI_UE_2014, media_FDI_UE_2017]
medias_fdi_Europeus=[media_FDI_Europeus_2010, media_FDI_Europeus_2014, media_FDI_Europeus_2017]
medias_fdi_NE=[media_FDI_NE_2010, media_FDI_NE_2014, media_FDI_NE_2017]

plt.scatter(anos,medias_fdi_UE, label = 'União Européia', color= 'r')
z = np.polyfit(anos, medias_fdi_UE, 1)
p = np.poly1d(z)
plt.plot(anos,p(anos),"r--")


plt.scatter(anos,medias_fdi_Europeus, label = 'Europeu não participante', color = 'g')
z = np.polyfit(anos, medias_fdi_Europeus, 1)
p = np.poly1d(z)
plt.plot(anos,p(anos),"g--")


plt.scatter(anos,medias_fdi_NE, label = 'Não Europeu', color = 'y')
z = np.polyfit(anos, medias_fdi_NE, 1)
p = np.poly1d(z)
plt.plot(anos,p(anos),"y--")


plt.legend(loc='center left', bbox_to_anchor=(1, 0.5))
plt.ylabel('Entrada de investimentos estrangeiros como % do PIB')
plt.xlabel('Anos')
plt.title('FDI')
plt.show()

# %% [markdown]
# ## Exportação:

# %%
fig = plt.figure(figsize=(15, 15))
def plots(grupo,coluna,nome,plot,cor,pos1,pos2):
    plt.subplot(plot)
    plot = grupo[coluna].plot.hist(bins=5, title='{0}: {1}'.format(nome, coluna), alpha=0.9, color=cor)
    plt.ylabel('Frequência Absoluta')
    plt.xlabel('Entrada de investimentos estrangeiros como % do PIB')
    verticalLine(plot, grupo[coluna].mean(), pos1, "darkgray", "Média")
    verticalLine(plot, grupo[coluna].median(), pos2, "black", "Mediana")

plots(uniao,'2010_Exports','UE',331,'r',15,12)
plots(uniao,'2014_Exports','UE',332,'r',15,12)
plots(uniao,'2017_Exports','UE',333,'r',15,12)
plots(euro,'2010_Exports','Europeus não participantes',334,'b',3.5,3)
plots(euro,'2014_Exports','Europeus não participantes',335,'b',2.7,2.3)
plots(euro,'2017_Exports','Europeus não participantes',336,'b',2.5,2)
plots(ne,'2010_Exports','Não Europeus',337,'yellow',80,70)
plots(ne,'2014_Exports','Não Europeus',338,'yellow',80,70)
plots(ne,'2017_Exports','Não Europeus',339,'yellow',70,60)

# %%
media_Exports_UE_2010= uniao['2010_Exports'].mean()
media_Exports_Europeus_2010= euro['2010_Exports'].mean()
media_Exports_NE_2010= ne['2010_Exports'].mean()

media_Exports_UE_2014= uniao['2014_Exports'].mean()
media_Exports_Europeus_2014= euro['2014_Exports'].mean()
media_Exports_NE_2014= ne['2014_Exports'].mean()

media_Exports_UE_2017= uniao['2017_Exports'].mean()
media_Exports_Europeus_2017= euro['2017_Exports'].mean()
media_Exports_NE_2017= ne['2017_Exports'].mean()

media_Exports_UE = (media_Exports_UE_2010 + media_Exports_UE_2014 + media_Exports_UE_2017)/3
media_Exports_Europeus= (media_Exports_Europeus_2010 + media_Exports_Europeus_2014 + media_Exports_Europeus_2017)/3
media_Exports_NE = (media_Exports_NE_2010 + media_Exports_NE_2014 + media_Exports_NE_2017)/3

medias_Exports = {'União Européia': media_Exports_UE , 'Europeus não participantes': media_Exports_Europeus , 'Não Europeus':media_Exports_NE}
names=list(medias_Exports.keys())
values=list(medias_Exports.values())

plt.bar(names,values, color = ('r','b','yellow'))
plt.title("Exportação")
plt.ylabel('Exportação como % do PIB')
plt.show()

# %%
anos= [2010,2014,2017]
medias_Exports_UE=[media_Exports_UE_2010, media_Exports_UE_2014, media_Exports_UE_2017]
medias_Exports_Europeus=[media_Exports_Europeus_2010, media_Exports_Europeus_2014, media_Exports_Europeus_2017]
medias_Exports_NE=[media_Exports_NE_2010, media_Exports_NE_2014, media_Exports_NE_2017]

plt.scatter(anos,medias_Exports_UE, label = 'União Européia', color= 'r')
z = np.polyfit(anos, medias_Exports_UE, 1)
p = np.poly1d(z)
plt.plot(anos,p(anos),"r--")


plt.scatter(anos,medias_Exports_Europeus, label = 'Europeu não participante', color = 'b')
z = np.polyfit(anos, medias_Exports_Europeus, 1)
p = np.poly1d(z)
plt.plot(anos,p(anos),"b--")


plt.scatter(anos,medias_Exports_NE, label = 'Não Europeu', color = 'y')
z = np.polyfit(anos, medias_Exports_NE, 1)
p = np.poly1d(z)
plt.plot(anos,p(anos),"y--")


plt.legend(loc='center left', bbox_to_anchor=(1, 0.5))
plt.ylabel('Exportação como % do PIB')
plt.xlabel('Anos')
plt.title('Exportação')
plt.show()

# %% [markdown]
# ## Índice de Desenvolvimento Humano:

# %%
fig = plt.figure(figsize=(15, 15))
def plots(grupo,coluna,nome,plot,cor,pos1,pos2):
    plt.subplot(plot)
    plot = grupo[coluna].plot.hist(bins=5, title='{0}: {1}'.format(nome, coluna), alpha=0.9, color=cor)
    plt.ylabel('Frequência Absoluta')
    plt.xlabel('Índice de Desenvolvimento Humano')
    verticalLine(plot, grupo[coluna].mean(), pos1, "r", "Média")
    verticalLine(plot, grupo[coluna].median(), pos2, "black", "Mediana")

plots(uniao,'2010_IDH','UE',331,'orange',7,6)
plots(uniao,'2013_IDH','UE',332,'orange',7,6)
plots(uniao,'2015_IDH','UE',333,'orange',7,6)
plots(euro,'2010_IDH','Europeus não participantes',334,'b',3.5,3)
plots(euro,'2013_IDH','Europeus não participantes',335,'b',2.7,2.3)
plots(euro,'2015_IDH','Europeus não participantes',336,'b',2.5,2)
plots(ne,'2010_IDH','Não Europeus',337,'g',35,30)
plots(ne,'2013_IDH','Não Europeus',338,'g',35,30)
plots(ne,'2015_IDH','Não Europeus',339,'g',35,30)

# %%
media_IDH_UE_2010= uniao['2010_IDH'].mean()
media_IDH_Europeus_2010= euro['2010_IDH'].mean()
media_IDH_NE_2010= ne['2010_IDH'].mean()

media_IDH_UE_2013= uniao['2013_IDH'].mean()
media_IDH_Europeus_2013= euro['2013_IDH'].mean()
media_IDH_NE_2013= ne['2013_IDH'].mean()

media_IDH_UE_2015= uniao['2015_IDH'].mean()
media_IDH_Europeus_2015= euro['2015_IDH'].mean()
media_IDH_NE_2015= ne['2015_IDH'].mean()

media_IDH_UE = (media_IDH_UE_2010 + media_IDH_UE_2013 + media_IDH_UE_2015)/3
media_IDH_Europeus= (media_IDH_Europeus_2010 + media_IDH_Europeus_2013 + media_IDH_Europeus_2015)/3
media_IDH_NE = (media_IDH_NE_2010 + media_IDH_NE_2013 + media_IDH_NE_2015)/3

medias_IDH = {'União Européia': media_IDH_UE , 'Europeus não participantes': media_IDH_Europeus , 'Não Europeus':media_IDH_NE}
names=list(medias_IDH.keys())
values=list(medias_IDH.values())

plt.bar(names,values, color = ('orange','b','g'))
plt.title("IDH")
plt.ylabel('Índice de Desenvolvimento Humano')
plt.show()

# %%
anos= [2010,2013,2015]
medias_IDH_UE=[media_IDH_UE_2010, media_IDH_UE_2013, media_IDH_UE_2015]
medias_IDH_Europeus=[media_IDH_Europeus_2010, media_IDH_Europeus_2013, media_IDH_Europeus_2015]
medias_IDH_NE=[media_IDH_NE_2010, media_IDH_NE_2013, media_IDH_NE_2015]

plt.scatter(anos,medias_IDH_UE, label = 'União Européia', color= 'orange')
z = np.polyfit(anos, medias_IDH_UE, 1)
p = np.poly1d(z)
plt.plot(anos,p(anos),"--", color = 'orange')


plt.scatter(anos,medias_IDH_Europeus, label = 'Europeu não participante', color = 'b')
z = np.polyfit(anos, medias_IDH_Europeus, 1)
p = np.poly1d(z)
plt.plot(anos,p(anos),"b--")


plt.scatter(anos,medias_IDH_NE, label = 'Não Europeu', color = 'g')
z = np.polyfit(anos, medias_IDH_NE, 1)
p = np.poly1d(z)
plt.plot(anos,p(anos),"g--")


plt.legend(loc='center left', bbox_to_anchor=(1, 0.5))
plt.ylabel('Índice de Desenvolvimento Humano')
plt.xlabel('Anos')
plt.title('IDH')
plt.show()

# %% [markdown]
# # Conclusão:

# %% [markdown]
# # Referências:
#
# https://econ.economicshelp.org/2007/03/benefits-of-european-union.html
#
# https://europa.eu/european-union/about-eu/eu-in-brief_en
#
# https://www.gapminder.org/data/
